# %%
from Code.WtoVec import W2VModel
from pprint import pprint

Greek = W2VModel("greek.1500e", "data/transformed/greek")
Greek.load()

NoCut = W2VModel("no-cut.no-pretrained.1500e", "data/transformed/no-cut")
NoCut.load()
HalfCut = W2VModel("half-cut.no-pretrained.1500e", "data/transformed/half-cut")
HalfCut.load()
ComCut = W2VModel("com-cut.no-pretrained.1500e", "data/transformed/com-cut")
ComCut.load()
SupCut = W2VModel("sup-cut.no-pretrained.1500e", "data/transformed/sup-cut")
SupCut.load()

NoCutPre = W2VModel("no-cut.pretrained.1500e", "data/transformed/no-cut")
NoCutPre.load()
HalfCutPre = W2VModel("half-cut.pretrained.1500e", "data/transformed/half-cut")
HalfCutPre.load()
ComCutPre = W2VModel("com-cut.pretrained.1500e", "data/transformed/com-cut")
ComCutPre.load()
SupCutPre = W2VModel("sup-cut.pretrained.1500e", "data/transformed/sup-cut")
SupCutPre.load()

# %% [markdown]
# # Having fun evaluating
#
# This journal is just here to run small by hand checkings

# %%
pprint(Greek.model.similar_by_word("χάρις"))

pprint(NoCut.model.similar_by_word("χάρις"))
pprint(HalfCut.model.similar_by_word("χάρις"))
pprint(ComCut.model.similar_by_word("χάρις"))
pprint(SupCut.model.similar_by_word("χάρις"))

pprint(NoCutPre.model.similar_by_word("χάρις"))
pprint(HalfCutPre.model.similar_by_word("χάρις"))
pprint(ComCutPre.model.similar_by_word("χάρις"))
pprint(SupCutPre.model.similar_by_word("χάρις"))
# Out:
# [('δειμαίνω', 0.40137964487075806),
#  ('ἀκριβής', 0.36117124557495117),
#  ('ψεῦδος', 0.33951079845428467),
#  ('ἔρνος', 0.314689576625824),
#  ('ἐκκηρύσσω', 0.3136780560016632),
#  ('πολίτευμα', 0.30518099665641785),
#  ('ὠφελέω', 0.30164170265197754),
#  ('ὄπισθεν', 0.3015963137149811),
#  ('λόγος', 0.2973458170890808),
#  ('Πειθώ', 0.29533350467681885)]
# [('προσχωρέω', 0.32509541511535645),
#  ('πεῖρα', 0.3235782980918884),
#  ('ὅλος', 0.3155766725540161),
#  ('εὐνομία', 0.3033539652824402),
#  ('σουδάριον', 0.3004997670650482),
#  ('στρέβλη', 0.30016860365867615),
#  ('Αδα', 0.29957348108291626),
#  ('Ασαηλ', 0.29919135570526123),
#  ('εὐστάθεια', 0.2965974509716034),
#  ('Ραουμ', 0.28955078125)]
# [('αὐτάρκης', 0.3646166920661926),
#  ('ἄνεσις', 0.3312450647354126),
#  ('ὀνειδισμός', 0.3283485174179077),
#  ('ἄγνοια', 0.3259316682815552),
#  ('γνώστης', 0.3224807381629944),
#  ('ἔπαινος', 0.3217962384223938),
#  ('αὐχήν', 0.3216857314109802),
# ...
